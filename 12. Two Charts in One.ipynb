# %% [markdown]
# # 1.导入所需要的包

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import random
import numpy as np
from matplotlib import font_manager
my_font = font_manager.FontProperties(fname='../data/STSONG.TTF')

# %% [markdown]
# # 2.示例数据，
# # cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
# # data1 = [89, 45, 56, 74, 23, 21]
# # data2 = [56, 77, 93, 68, 45, 67]
# # data3 = [153, 124, 107, 99, 89, 46]

# %%
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data1 = [89, 45, 56, 74, 23, 21]
data2 = [56, 77, 93, 68, 45, 67]
data3 = [153, 124, 107, 99, 89, 46]

# %% [markdown]
# # 3.新建一个空画布(8, 5)
# # 4.设置刻度
# # 5.为X轴设置刻度值
# # 6.把数据data1和data2加入到图中，并设置为标签为 线上  线下
# # 7.添加图例
# # 8.设置标题字体大小和颜色
# # 9.显示这个图片

# %%
#构造一个画板
plt.figure(figsize=(8, 5),dpi=80)  

#添加描述信息
x_location = np.arange(len(cate))
plt.bar(x_location, data1, label='线下', width=0.3)
plt.bar(x_location+0.3, data2, label='线上',width=0.3)
plt.xticks(x_location+0.15, cate)
plt.legend(prop=my_font)

plt.title('各手机品牌销售额对比', loc="left", fontdict={'fontsize':28,'color':'black'},fontproperties=my_font)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # 10.画出各个数据的饼状图
# # 11.使用data3和cate

# %%
plt.figure(figsize=(20,8),dpi=80)
plt.pie(data3,labels=cate,autopct='%.2f%%')
plt.show()
